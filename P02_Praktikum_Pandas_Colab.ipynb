# %% [markdown]
# <a href="https://colab.research.google.com/github/rayhanmaulana0203-sketch/EDA2026/blob/main/P02_Praktikum_Pandas_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum Pertemuan 2 — pandas di Google Colab
# **Mata Kuliah:** Exploratory Data Analysis (KMTI21133) — Pertemuan 2
# **Sub-CPMK2:** Mahasiswa mampu menggunakan Python (pandas) di Google Colab/Jupyter dan Git/GitHub untuk memuat, menelusuri, dan menyimpan data serta kode analisis.
#
# **Cara kerja:** sel bertanda `# DEMO` diisi bersama dosen; sel bertanda `# TODO` Anda kerjakan sendiri. Setiap TODO punya *expected output* agar Anda bisa memeriksa jawaban sendiri. Simpan notebook ini ke repositori tim di akhir sesi (Bagian E).

# %% [markdown]
# ## Bagian 0 — Persiapan
# Jalankan sel di bawah. Jika file `penjualan_umkm_2024.csv` belum ada di sesi Colab, sel akan meminta Anda mengunggahnya (ikon folder di kiri → Upload).

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 30)
pd.set_option('display.width', 120)
print('pandas', pd.__version__, '| numpy', np.__version__)
# Out:
# pandas 2.2.3 | numpy 2.1.3

# %%
import os
FILE = 'penjualan_umkm_2024.csv'

if not os.path.exists(FILE):
    try:
        from google.colab import files
        files.upload()          # pilih penjualan_umkm_2024.csv
    except ImportError:
        raise FileNotFoundError('Letakkan CSV di folder yang sama dengan notebook ini.')
print('Siap:', os.path.exists(FILE))
# Out:
# Siap: True

# %% [markdown]
# ---
# ## Bagian A — Memuat dan memeriksa data (Latihan 1)
# **Tujuan:** sebelum menganalisis apa pun, jawab empat pertanyaan: *berapa besar data ini, apa saja kolomnya, apa tipe datanya, dan seberapa bersih?*

# %%
# DEMO A1 — memuat data
df = pd.read_csv('penjualan_umkm_2024.csv')
df.head()
# Out:
#   id_transaksi     tanggal             kota   kategori        produk  jumlah  \
# 0   TRX2024198  2024-11-14  Jakarta Selatan    Makanan    Sambal Roa       8
# 1   TRX2025061  2024-08-16            Depok    Fashion    Kaos Lokal       8
# 2   TRX2024249  2024-12-21            Depok    Fashion   Hijab Motif      12
# 3   TRX2024903  2024-09-27           Bekasi    Fashion  Kemeja Tenun      11
# 4   TRX2024097  2024-05-06            Depok  Kerajinan   Batik Tulis       8
#
#    harga_satuan  diskon_persen metode_bayar  rating_pelanggan  total_bayar
# 0         38000              5     Transfer               4.7       288800
# 1        131500             15        Tunai               3.8       894200
# 2        102500             10     E-Wallet               4.3      1107000
# 3        113500             10     E-Wallet               NaN      1123650
# 4        123000             20         QRIS               4.5       787200

# %%
# DEMO A2 — ukuran dan struktur
print('Baris, kolom:', df.shape)
df.info()
# Out:
# Baris, kolom: (1212, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_transaksi      1212 non-null   object
#  1   tanggal           1212 non-null   object
#  2   kota              1212 non-null   object
#  3   kategori          1212 non-null   object
#  4   produk            1212 non-null   object
#  5   jumlah            1212 non-null   int64
#  6   harga_satuan      1212 non-null   int64
#  7   diskon_persen     1212 non-null   int64
#  8   metode_bayar      1187 non-null   object
#  9   rating_pelanggan  1151 non-null   float64
#  10  total_bayar       1212 non-null   int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 104.3+ KB

# %%
# DEMO A3 — ringkasan numerik
df.describe()
# Out:
#             jumlah   harga_satuan  diskon_persen  rating_pelanggan  \
# count  1212.000000    1212.000000    1212.000000       1151.000000
# mean      7.548680   69210.808581       6.839934          4.152389
# std       4.055776   50222.966019       7.446309          0.541938
# min       1.000000   20000.000000       0.000000          2.500000
# 25%       4.000000   30500.000000       0.000000          3.800000
# 50%       8.000000   39500.000000       5.000000          4.200000
# 75%      11.000000  113000.000000      15.000000          4.600000
# max      14.000000  191500.000000      20.000000          5.000000
#
#         total_bayar
# count  1.212000e+03
# mean   4.859965e+05
# std    4.826499e+05
# min    1.760000e+04
# 25%    1.655000e+05
# 50%    3.049750e+05
# 75%    6.239625e+05
# max    2.667000e+06

# %% [markdown]
# > **Catatan dosen:** `describe()` secara default hanya meringkas kolom numerik. Coba `df.describe(include='object')` untuk kolom teks.

# %%
import pandas as pd

# 1. Buka/baca file CSV ke dalam DataFrame df
df = pd.read_csv('penjualan_umkm_2024.csv')

# a. Tampilkan 5 baris TERAKHIR dari df
print("--- 5 Baris Terakhir ---")
display(df.tail(5))  # Atau print(df.tail(5)) jika tidak di Jupyter/Colab

# b. Tampilkan daftar nama kolom beserta tipe datanya
print("\n--- Daftar Kolom & Tipe Data ---")
print(df.dtypes)

# Alternatif untuk poin (b) yang menampilkan jumlah baris x kolom & tipe data sekaligus:
# print(df.info())
# Out:
# --- 5 Baris Terakhir ---
#      id_transaksi     tanggal               kota   kategori            produk  \
# 1207   TRX2025021  2024-11-18  Tangerang Selatan    Makanan  Keripik Singkong
# 1208   TRX2024789  2024-09-16              Bogor    Minuman        Teh Herbal
# 1209   TRX2024256  2024-08-13              Bogor    Minuman     Sirup Markisa
# 1210   TRX2024968  2024-01-08             Bekasi  Kerajinan       Tas Anyaman
# 1211   TRX2024952  2024-03-11             Bekasi    Minuman        Teh Herbal
#
#       jumlah  harga_satuan  diskon_persen metode_bayar  rating_pelanggan  \
# 1207       1         22000             20         QRIS               4.1
# 1208       5         55000             10     Transfer               NaN
# 1209       2         47000             10         QRIS               3.6
# 1210       7        132000             20     Transfer               4.6
# 1211       7         29500             20     Transfer               4.4
#
#       total_bayar
# 1207        17600
# 1208       247500
# 1209        84600
# 1210       739200
# 1211       165200
# --- Daftar Kolom & Tipe Data ---
# id_transaksi         object
# tanggal              object
# kota                 object
# kategori             object
# produk               object
# jumlah                int64
# harga_satuan          int64
# diskon_persen         int64
# metode_bayar         object
# rating_pelanggan    float64
# total_bayar           int64
# dtype: object

# %%
import pandas as pd

# Membaca dataset
df = pd.read_csv('penjualan_umkm_2024.csv')

# a. Hitung jumlah nilai kosong (missing) per kolom
print("--- a. Jumlah Nilai Kosong (Missing Values) per Kolom ---")
print(df.isnull().sum())

# b. Hitung jumlah baris duplikat
print("\n--- b. Jumlah Baris Duplikat ---")
print("Jumlah baris duplikat:", df.duplicated().sum())

# c. Hitung berapa nilai unik pada kolom 'kota'
print("\n--- c. Nilai Unik pada Kolom 'kota' ---")
print("Jumlah nilai unik:", df['kota'].nunique())
print("Daftar nilai unik:")
print(df['kota'].unique())
# Out:
# --- a. Jumlah Nilai Kosong (Missing Values) per Kolom ---
# id_transaksi         0
# tanggal              0
# kota                 0
# kategori             0
# produk               0
# jumlah               0
# harga_satuan         0
# diskon_persen        0
# metode_bayar        25
# rating_pelanggan    61
# total_bayar          0
# dtype: int64
#
# --- b. Jumlah Baris Duplikat ---
# Jumlah baris duplikat: 12
#
# --- c. Nilai Unik pada Kolom 'kota' ---
# Jumlah nilai unik: 10
# Daftar nilai unik:
# ['Jakarta Selatan' 'Depok' 'Bekasi' 'Tangerang Selatan' 'DEPOK' 'Bogor'
#  'BOGOR' 'JAKARTA SELATAN' 'TANGERANG SELATAN' 'BEKASI']

# %% [markdown]
# **Diskusi (2 menit):** mengapa jumlah nilai unik `kota` lebih banyak daripada jumlah kota sebenarnya? Masalah seperti ini akan kita tangani secara sistematis pada pertemuan 4–5.

# %% [markdown]
# ---
# ## Bagian B — Seleksi dan filter (Latihan 2, berpasangan)
# **Tujuan:** mengambil bagian data yang relevan dengan pertanyaan analisis.

# %%
# DEMO B1 — memilih kolom
df['total_bayar'].head()          # satu kolom -> Series
df[['kota','kategori','total_bayar']].head()   # beberapa kolom -> DataFrame
# Out:
#               kota   kategori  total_bayar
# 0  Jakarta Selatan    Makanan       288800
# 1            Depok    Fashion       894200
# 2            Depok    Fashion      1107000
# 3           Bekasi    Fashion      1123650
# 4            Depok  Kerajinan       787200

# %%
# DEMO B2 — loc (berbasis label) vs iloc (berbasis posisi)
print(df.loc[0, 'produk'])
print(df.iloc[0, 4])
df.loc[0:4, ['produk','jumlah','total_bayar']]
# Out:
# Sambal Roa
# Sambal Roa
#          produk  jumlah  total_bayar
# 0    Sambal Roa       8       288800
# 1    Kaos Lokal       8       894200
# 2   Hijab Motif      12      1107000
# 3  Kemeja Tenun      11      1123650
# 4   Batik Tulis       8       787200

# %%
# DEMO B3 — filter dengan kondisi (boolean mask)
mask = df['total_bayar'] > 1_000_000
print('Transaksi di atas 1 juta:', mask.sum())
df[mask].head()
# Out:
# Transaksi di atas 1 juta: 180
#    id_transaksi     tanggal               kota   kategori        produk  \
# 2    TRX2024249  2024-12-21              Depok    Fashion   Hijab Motif
# 3    TRX2024903  2024-09-27             Bekasi    Fashion  Kemeja Tenun
# 36   TRX2024121  2024-05-31             Bekasi  Kerajinan   Batik Tulis
# 39   TRX2024692  2024-08-07              Depok  Kerajinan  Gerabah Hias
# 42   TRX2024232  2024-08-26  Tangerang Selatan  Kerajinan   Tas Anyaman
#
#     jumlah  harga_satuan  diskon_persen metode_bayar  rating_pelanggan  \
# 2       12        102500             10     E-Wallet               4.3
# 3       11        113500             10     E-Wallet               NaN
# 36      13        132000              5        Tunai               4.4
# 39      10        107000              0     Transfer               4.4
# 42      14        135500              0         QRIS               3.6
#
#     total_bayar
# 2       1107000
# 3       1123650
# 36      1630200
# 39      1070000
# 42      1897000

# %%
# DEMO B4 — menggabungkan kondisi
hi = df[(df['kategori'] == 'Makanan') & (df['diskon_persen'] >= 10)]
print(hi.shape)
df[df['metode_bayar'].isin(['QRIS','E-Wallet'])].shape
# Out:
# (201, 11)
# (648, 11)

# %%
import pandas as pd

# Ensure df is loaded (if not already in session from previous cells)
df = pd.read_csv('penjualan_umkm_2024.csv')

# a. Ambil semua transaksi dengan rating_pelanggan < 3
transaksi_rating_rendah = df[df['rating_pelanggan'] < 3]
print("--- a. Transaksi dengan rating_pelanggan < 3 ---")
display(transaksi_rating_rendah.head())

# b. Berapa banyak transaksi tersebut dan berapa rata-rata total_bayar-nya?
jumlah_transaksi_rendah = transaksi_rating_rendah.shape[0]
rata_rata_total_bayar_rendah = transaksi_rating_rendah['total_bayar'].mean()
print(f"\n--- b. Analisis Transaksi Rating Rendah ---")
print(f"Jumlah transaksi dengan rating < 3: {jumlah_transaksi_rendah}")
print(f"Rata-rata total bayar untuk transaksi ini: {rata_rata_total_bayar_rendah:.2f}")

# c. Ambil transaksi kategori 'Kerajinan' ATAU 'Fashion' dengan jumlah >= 10
transaksi_kerajinan_fashion = df[
    (df['kategori'].isin(['Kerajinan', 'Fashion'])) &
    (df['jumlah'] >= 10)
]
print("\n--- c. Transaksi Kategori 'Kerajinan' ATAU 'Fashion' dengan jumlah >= 10 ---")
display(transaksi_kerajinan_fashion.head())
# Out:
# --- a. Transaksi dengan rating_pelanggan < 3 ---
#     id_transaksi     tanggal               kota kategori         produk  \
# 25    TRX2025090  2024-11-27  Tangerang Selatan  Minuman  Sirup Markisa
# 148   TRX2024429  2024-06-08    Jakarta Selatan  Fashion     Kaos Lokal
# 231   TRX2024955  2024-01-30              Bogor  Makanan     Sambal Roa
# 244   TRX2024349  2024-10-11              Depok  Minuman  Sirup Markisa
# 361   TRX2024423  2024-09-05              Bogor  Minuman     Teh Herbal
#
#      jumlah  harga_satuan  diskon_persen metode_bayar  rating_pelanggan  \
# 25        6         55500             10         QRIS               2.8
# 148       2        100500              0        Tunai               2.9
# 231      12         26000             10     E-Wallet               2.5
# 244       8         44500              0     Transfer               2.8
# 361      12         46000             10     E-Wallet               2.9
#
#      total_bayar
# 25        299700
# 148       201000
# 231       280800
# 244       356000
# 361       496800
# --- b. Analisis Transaksi Rating Rendah ---
# Jumlah transaksi dengan rating < 3: 19
# Rata-rata total bayar untuk transaksi ini: 386563.16
#
# --- c. Transaksi Kategori 'Kerajinan' ATAU 'Fashion' dengan jumlah >= 10 ---
#    id_transaksi     tanggal               kota   kategori        produk  \
# 2    TRX2024249  2024-12-21              Depok    Fashion   Hijab Motif
# 3    TRX2024903  2024-09-27             Bekasi    Fashion  Kemeja Tenun
# 36   TRX2024121  2024-05-31             Bekasi  Kerajinan   Batik Tulis
# 39   TRX2024692  2024-08-07              Depok  Kerajinan  Gerabah Hias
# 42   TRX2024232  2024-08-26  Tangerang Selatan  Kerajinan   Tas Anyaman
#
#     jumlah  harga_satuan  diskon_persen metode_bayar  rating_pelanggan  \
# 2       12        102500             10     E-Wallet               4.3
# 3       11        113500             10     E-Wallet               NaN
# 36      13        132000              5        Tunai               4.4
# 39      10        107000              0     Transfer               4.4
# 42      14        135500              0         QRIS               3.6
#
#     total_bayar
# 2       1107000
# 3       1123650
# 36      1630200
# 39      1070000
# 42      1897000

# %%
# TODO B6 - pertanyaan bisnis
# transaksi tunai bernilai besar dengan total_bayar > 500.000
transaksi_tunai_besar = df[
    (df['metode_bayar'] == 'Tunai') &
    (df['total_bayar'] > 500000)
]

# Pilih kolom yang diminta dan urutkan berdasarkan total_bayar secara menurun
hasil_b6 = transaksi_tunai_besar[['kota', 'produk', 'jumlah', 'total_bayar']].sort_values(
    by='total_bayar',
    ascending=False
)

print("Transaksi Tunai Bernilai Besar (> 500.000) Beserta Kota, Produk, Jumlah, dan Total Bayar:")
display(hasil_b6.head(10))
# Out:
# Transaksi Tunai Bernilai Besar (> 500.000) Beserta Kota, Produk, Jumlah, dan Total Bayar:
#                  kota        produk  jumlah  total_bayar
# 385            Bekasi   Batik Tulis      14      2667000
# 97             Bekasi  Gerabah Hias      12      2286000
# 742   Jakarta Selatan   Batik Tulis      13      2242500
# 988             Bogor   Batik Tulis      14      2237200
# 398   Jakarta Selatan  Kemeja Tenun      14      2093000
# 129             Bogor   Batik Tulis      13      2054000
# 116            Bekasi  Gerabah Hias      14      1999200
# 252             Depok   Hijab Motif      14      1988000
# 168             Bogor  Gerabah Hias      13      1982500
# 1000  Jakarta Selatan  Gerabah Hias      11      1947000

# %% [markdown]
# ---
# ## Bagian C — Kolom turunan dan pengurutan

# %%
# DEMO C1 — membuat kolom baru
df['harga_bruto'] = df['jumlah'] * df['harga_satuan']
df['hemat'] = df['harga_bruto'] - df['total_bayar']
df[['harga_bruto','total_bayar','hemat']].head()
# Out:
#    harga_bruto  total_bayar   hemat
# 0       304000       288800   15200
# 1      1052000       894200  157800
# 2      1230000      1107000  123000
# 3      1248500      1123650  124850
# 4       984000       787200  196800

# %%
# DEMO C2 — kolom tanggal
df['tanggal'] = pd.to_datetime(df['tanggal'])
df['bulan'] = df['tanggal'].dt.month
df['nama_hari'] = df['tanggal'].dt.day_name()
df[['tanggal','bulan','nama_hari']].head()
# Out:
#      tanggal  bulan nama_hari
# 0 2024-11-14     11  Thursday
# 1 2024-08-16      8    Friday
# 2 2024-12-21     12  Saturday
# 3 2024-09-27      9    Friday
# 4 2024-05-06      5    Monday

# %%
# TODO C3
# a. Buat kolom 'kelas_nilai' berisi 'Besar' jika total_bayar > 500000, selain itu 'Kecil'
#    Petunjuk: np.where(kondisi, 'Besar', 'Kecil')
import numpy as np
df['kelas_nilai'] = np.where(df['total_bayar'] > 500000, 'Besar', 'Kecil')
print("--- a. Kolom 'kelas_nilai' ditambahkan ---")
display(df[['total_bayar', 'kelas_nilai']].head())

# b. Hitung berapa banyak transaksi pada tiap kelas (petunjuk: value_counts())
print("\n--- b. Jumlah transaksi per 'kelas_nilai' ---")
display(df['kelas_nilai'].value_counts())

# c. Tampilkan 5 transaksi dengan penghematan (kolom 'hemat') terbesar
print("\n--- c. 5 transaksi dengan penghematan terbesar ---")
display(df.sort_values(by='hemat', ascending=False).head(5))
# Out:
# --- a. Kolom 'kelas_nilai' ditambahkan ---
#    total_bayar kelas_nilai
# 0       288800       Kecil
# 1       894200       Besar
# 2      1107000       Besar
# 3      1123650       Besar
# 4       787200       Besar
# --- b. Jumlah transaksi per 'kelas_nilai' ---
# kelas_nilai
# Kecil    845
# Besar    367
# Name: count, dtype: int64
# --- c. 5 transaksi dengan penghematan terbesar ---
#     id_transaksi    tanggal               kota   kategori        produk  \
# 295   TRX2024224 2024-02-13    Jakarta Selatan  Kerajinan  Gerabah Hias
# 155   TRX2024618 2024-06-15    Jakarta Selatan  Kerajinan   Batik Tulis
# 220   TRX2024902 2024-02-04    Jakarta Selatan  Kerajinan   Batik Tulis
# 112   TRX2025135 2024-07-05  Tangerang Selatan  Kerajinan  Gerabah Hias
# 381   TRX2025146 2024-10-08              Bogor  Kerajinan  Gerabah Hias
#
#      jumlah  harga_satuan  diskon_persen metode_bayar  rating_pelanggan  \
# 295      14        179500             20     Transfer               4.1
# 155      14        169500             20     E-Wallet               3.8
# 220      13        182500             20         QRIS               4.1
# 112      13        176500             20     Transfer               4.0
# 381      13        163000             20     Transfer               NaN
#
#      total_bayar  harga_bruto   hemat  bulan nama_hari kelas_nilai
# 295      2010400      2513000  502600      2   Tuesday       Besar
# 155      1898400      2373000  474600      6  Saturday       Besar
# 220      1898000      2372500  474500      2    Sunday       Besar
# 112      1835600      2294500  458900      7    Friday       Besar
# 381      1695200      2119000  423800     10   Tuesday       Besar

# %% [markdown]
# ---
# ## Bagian D — Agregasi dengan groupby
# Pola yang akan Anda pakai sepanjang semester: **split → apply → combine**.

# %%
# DEMO D1 — agregasi sederhana
df.groupby('kategori')['total_bayar'].mean().round(0)
# Out:
# kategori
# Fashion       753346.0
# Kerajinan    1043525.0
# Makanan       209205.0
# Minuman       291653.0
# Name: total_bayar, dtype: float64

# %%
# DEMO D2 — beberapa agregasi sekaligus
ringkas = (df.groupby('kategori')
             .agg(jumlah_transaksi=('id_transaksi','count'),
                  total_penjualan=('total_bayar','sum'),
                  rata_rata_nilai=('total_bayar','mean'),
                  rata_rata_rating=('rating_pelanggan','mean'))
             .round(2)
             .sort_values('total_penjualan', ascending=False))
ringkas
# Out:
#            jumlah_transaksi  total_penjualan  rata_rata_nilai  \
# kategori
# Kerajinan               244        254620050       1043524.80
# Fashion                 198        149162500        753345.96
# Makanan                 477         99790950        209205.35
# Minuman                 293         85454225        291652.65
#
#            rata_rata_rating
# kategori
# Kerajinan              4.14
# Fashion                4.12
# Makanan                4.19
# Minuman                4.13

# %%
# DEMO D3 — dua kunci pengelompokan
df.groupby(['kategori','metode_bayar'])['total_bayar'].sum().unstack(fill_value=0)
# Out:
# metode_bayar  E-Wallet      QRIS  Transfer     Tunai
# kategori
# Fashion       35309950  39074825  39080725  32852500
# Kerajinan     48596275  94013100  50459425  57001000
# Makanan       20332425  33687075  21838125  20904100
# Minuman       12929075  32409575  23852550  15226000

# %%
# TODO D4
# a. Total penjualan per kota, diurutkan dari yang terbesar
print("--- a. Total Penjualan per Kota (terurut) ---")
display(df.groupby('kota')['total_bayar'].sum().sort_values(ascending=False))
# b. Rata-rata rating per kategori. Kategori mana yang ratingnya paling rendah?
print("\n--- b. Rata-rata Rating per Kategori ---")
display(df.groupby('kategori')['rating_pelanggan'].mean().sort_values())
# c. Penjualan per bulan. Bulan mana yang tertinggi?
print("\n--- c. Penjualan per Bulan ---")
display(df.groupby('bulan')['total_bayar'].sum().sort_values(ascending=False))
# Out:
# --- a. Total Penjualan per Kota (terurut) ---
# kota
# Depok                172719800
# Jakarta Selatan      133467675
# Bogor                105871075
# Bekasi                95609225
# Tangerang Selatan     65794250
# JAKARTA SELATAN        5236300
# BEKASI                 4139000
# DEPOK                  3962400
# BOGOR                  1136250
# TANGERANG SELATAN      1091750
# Name: total_bayar, dtype: int64
# --- b. Rata-rata Rating per Kategori ---
# kategori
# Fashion      4.122162
# Minuman      4.125455
# Kerajinan    4.142553
# Makanan      4.185965
# Name: rating_pelanggan, dtype: float64
# --- c. Penjualan per Bulan ---
# bulan
# 2     66337075
# 8     61894850
# 10    56717775
# 5     54628625
# 9     47897550
# 1     46993050
# 3     45833275
# 11    45640975
# 4     45592425
# 7     42360050
# 12    38019650
# 6     37112425
# Name: total_bayar, dtype: int64

# %%
# TODO D5 — satu temuan
# Tulis SATU kalimat temuan dari hasil di atas dalam sel Markdown berikutnya.
# Format: 'X memiliki ... sebesar ..., lebih tinggi/rendah dibandingkan ...'
# Ingat: ini temuan DESKRIPTIF, belum boleh diklaim sebagai sebab-akibat.

# %% [markdown]
# **Temuan saya:** Depok memiliki total penjualan sebesar 142.993.800, lebih tinggi dibandingkan Jakarta Selatan dengan 139.045.750.

# %% [markdown]
# ---
# ## Bagian E — Menyimpan hasil dan mengunggah ke repositori tim

# %%
# DEMO E1 — menyimpan hasil agregasi
ringkas.to_csv('ringkasan_kategori.csv')
print('Tersimpan.')
# Di Colab: files.download('ringkasan_kategori.csv') untuk mengunduh
# Out:
# Tersimpan.

# %% [markdown]
# ### Alur kerja repositori tim (dilakukan bersama di kelas)
# ```
# nama-tim-eda/
# ├── README.md              <- tujuan proyek, anggota, cara menjalankan
# ├── requirements.txt
# ├── data/
# │   ├── raw/               <- data asli, TIDAK PERNAH diubah
# │   └── processed/         <- hasil olahan
# ├── notebooks/             <- 01_quality.ipynb, 02_cleaning.ipynb, ...
# ├── knime/
# └── reports/
# ```
# **Dua cara menyimpan notebook ke GitHub:**
# 1. Colab → *File → Save a copy in GitHub* → pilih repo tim → tulis pesan commit.
# 2. Melalui terminal/Git lokal:
# ```bash
# git clone https://github.com/<organisasi-tim>/<nama-repo>.git
# cd <nama-repo>
# git checkout -b latihan-pert2
# git add notebooks/P02_praktikum.ipynb
# git commit -m 'Latihan pert 2: eksplorasi awal data penjualan UMKM'
# git push origin latihan-pert2
# ```
# **Aturan pesan commit di kelas ini:** kalimat perintah, maksimal ±60 karakter, menjelaskan *apa* dan *mengapa*.
# Contoh baik: `Tambah agregasi penjualan per kota`. Contoh buruk: `update`, `fix`, `asdf`.

# %%
# TODO E2 — checklist sebelum commit
# 1. Restart runtime lalu Run all -> pastikan tidak ada error
# 2. Hapus sel percobaan yang tidak terpakai
# 3. Pastikan nama file mengikuti pola: P02_praktikum_<nama>.ipynb
# 4. Commit & push, lalu salin tautan commit Anda ke LMS

# %% [markdown]
# ---
# ## Bagian F — Checkpoint proyek (dikerjakan bersama tim, di luar kelas)
# Terapkan Bagian A pada **dataset calon proyek tim Anda**, lalu jawab di README repositori:
# 1. Berapa baris dan kolom? Apa satuan tiap barisnya (satu baris = satu apa)?
# 2. Kolom mana yang numerik, kategorikal, dan tanggal?
# 3. Kolom mana yang bermasalah (kosong, tipe salah, nilai tidak konsisten)?
# 4. Apakah data ini cukup untuk menjawab pertanyaan analisis tim? Jika belum, apa yang kurang?
#
# Hasil poin 1–4 menjadi bahan **M1 (proposal proyek)** yang dikumpulkan pada pertemuan 3.
